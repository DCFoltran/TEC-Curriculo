// %% [markdown]
// <a href="https://colab.research.google.com/github/DCFoltran/TEC-Curriculo/blob/main/rust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %%
!curl --proto '=https' --tlsv1.2 -sSf https://rustup.rs | sh -s -- -y
!source $HOME/.cargo/env
!cargo install evcxr_jupyter
!evcxr_jupyter --install
// Out:
// sh: 2: Syntax error: newline unexpected
// /bin/bash: line 1: /root/.cargo/env: No such file or directory
// /bin/bash: line 1: cargo: command not found
// /bin/bash: line 1: evcxr_jupyter: command not found

// %%
# run this once, then reload, and then skip this
!apt install rustc
!gdown --id 1PULtTc-2e9z4bswh_SQqL5oy_4JpfV7c
!chmod +x evcxr_jupyter
!./evcxr_jupyter --install

// %%
println!("Hello, world!");

// %%
// install a library for calling shell command
:dep cmd_lib
use cmd_lib::run_cmd as sh;

// %%
sh!(ls -al)
